# %%
import time
print(time.ctime())
# Out:
# Wed Feb 15 08:40:41 2023

# %%
import numpy as np
x = np.array([1,2,3])
y = np.array([[1,4,3],[9,2,7]])
x
# Out:
# array([1, 2, 3])

# %%
def hitung_angka(a, b, c):
    """
    function to sum the 3 numbers
    Input: 3 numbers a, b, c
    Output: th sum of a, b, and c
    author:
    date:
    """

    #this is the summation
    out = a + b + c
    return out

# %%
a = int
b = int
c = int
a, b, c = input("Input = ").split()
hitung_angka(a, b, c)

# %%
def my_thermo_stat(temp, desired_temp):
    if temp < desired_temp - 5:
        status = "Heat"
    else temp > desired_temp + 5:
        status = "AC"
    else:
      status = "Off"
    return status

# %%
x = 1
y = 2
print("x =", x)
print("y =", y)
# Out:
# x = 1
# y = 2

# %%
help(hitung_angka)
# Out:
# Help on function hitung_angka in module __main__:
#
# hitung_angka(a, b, c)
#     function to sum the 3 numbers
#     Input: 3 numbers a, b, c
#     Output: th sum of a, b, and c
#     author:
#     date:

# %%
x = 1
y = x + 1
x = 2
y
# Out:
# 2
